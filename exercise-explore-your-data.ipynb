# %% [markdown]
# **[Machine Learning Course Home Page](https://www.kaggle.com/learn/machine-learning)**
#
# ---

# %% [markdown]
# 이 연습은 데이터 파일을 읽고 데이터에 대한 통계를 이해하는 능력을 테스트합니다.
#
# 이후 연습에서는 데이터를 필터링하고, 기계 학습 모델을 구축하고, 모델을 반복적으로 개선하는 기술을 적용합니다.
#
# 코스 예제는 멜버른의 데이터를 사용합니다. 이러한 기술을 직접 적용하려면 새 데이터 세트(아이오와의 주택 가격 포함)에 적용해야 합니다.
#
# 연습은 "노트북" 코딩 환경을 사용합니다. 노트북에 익숙하지 않은 분들을 위해 [90초 소개 동영상](https://www.youtube.com/watch?v=4C2qMnaIKL4)이 있습니다.

# %%
# !pip install learntools

# %%
# Set up code checking
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex2 import *

# %% [markdown]
# ## Step 1: Loading Data
# Iowa 데이터 파일을 `home_data`라는 Pandas DataFrame으로 읽어들입니다.

# %%
import pandas as pd

# Path of the file to read
iowa_file_path = r'C:\Users\kr937\Desktop\drive\Kaggle\train (2).csv'

# 파일을 변수 home_data로 읽으려면 아래 줄을 채우십시오.
home_data = pd.read_csv(iowa_file_path)

# Call line below with no argument to check that you've loaded the data correctly
step_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#step_1.hint()
step_1.solution()
# Out:
# Solution:
# ```python
# home_data = pd.read_csv(iowa_file_path)
# ```

# %% [markdown]
# ## Step 2: Review The Data
# Use the command you learned to view summary statistics of the data. Then fill in variables to answer the following questions

# %%
# 다음 줄에 요약 통계 
home_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
home_data[home_data['YearBuilt'] == 2010]
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 378  379          20       RL         88.0    11394   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 378         Lvl    AllPub    Corner       Gtl      StoneBr       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 378       Norm     1Fam     1Story            9            2       2010
#
#      YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 378          2010       Hip  CompShg     VinylSd     VinylSd      Stone
#
#      MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 378       350.0        Gd        TA      PConc       Ex       TA           Av
#
#     BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 378          GLQ        1445          Unf           0        411         1856
#
# ...

# %% [markdown]
# ID = 번호
# MSSubClass = 주택의 건물 유형
# MSZoning = 토지 사용 구역(RL은 주거 구역, RMd은 중밀도 주거 구역, C (all)은 상업 및 산업 구역)
# LotFrontage = 부지의 도로와 인접한 선형 피트(길이)(큰 LotFrontage 값은 일반적으로 더 큰 부지 크기를 나타냄)
# LotArea = 부지의 면적
# Street = 도로 포장 유무(Pave: 포장, Grvl: 비포장)
# Alley = 주택이나 부동산에 연결된 골목길 또는 좁은 통로
# LotShape = 부지의 형태
# Utilities = 주택이나 부동산에 제공되는 공공 서비스 및 유틸리티의 유무( "AllPub"은 모든 공공 유틸리티 서비스가 연결된 주택, "NoSewr"은 하수 시스템이 연결되지 않은 주택)

# %%
newest_home_age = 2023 - home_data[['YearBuilt']]
newest_home_age.min()
# Out:
# YearBuilt    13
# dtype: int64

# %%
2023 - home_data[['YearBuilt']].max()
# Out:
# YearBuilt    13
# dtype: int64

# %%
round(home_data['LotArea'].mean())
# Out:
# 10517

# %%
# 평균 부지 크기 (가장 가까운 정수로 반올림)
avg_lot_size = 10517

# 가장최근에 지어진 집이 몇년 되었는지 (현재년도 - 건축연도)
newest_home_age = 13

# Checks your answers
step_2.check()
# Out:
# Correct

# %%
#step_2.hint()
#step_2.solution()

# %% [markdown]
# ## 데이터에 대해 생각해보기
#
#
# 데이터에서 가장 최근에 지어진 집은 새 집이 아닙니다. 이에 대한 몇 가지 가능한 설명:
# 1. 그들은 이 데이터가 수집된 곳에 새 집을 짓지 않았습니다.
# 2. 이 데이터는 오래전에 수집되었습니다. 데이터 게시 이후에 지어진 집은 표시되지 않습니다..
#
# 위의 설명이 첫번째의 이유라면 이 데이터로 만든 모델의 신뢰도에 영향을 미칠거인가? 만약 두번째 이유라면?
# If the reason is explanation #1 above, does that affect your trust in the model you build with this data? What about if it is reason #2?
#
# 어떤 설명이 더 타당한지 확인하기 위해 어떻게 데이터를 파헤칠 수 있습니까?
#
# Check out this **[discussion thread](https://www.kaggle.com/learn-forum/60581)** to see what others think or to add your ideas.
#
# # Keep Going
#
# You are ready for **[Your First Machine Learning Model](https://www.kaggle.com/dansbecker/your-first-machine-learning-model).**

# %% [markdown]
# ---
# **[Machine Learning Course Home Page](https://www.kaggle.com/learn/machine-learning)**
